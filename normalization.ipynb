# %%
import pandas as pd 
import numpy as np

# %%
header_list = ["img_id", "class", "cx", "cy", "w", "h"]
train_labels = pd.read_csv("train/labels.txt", names=header_list, sep=" ")
val_labels = pd.read_csv("val/labels.txt", names=header_list, sep=" ")

# %%
# Change class range from 1-7 to 0-6 in yolo format
train_labels['class'] = train_labels['class'] - 1
val_labels['class'] = val_labels['class'] - 1

# %%
#Normalize training data 
w_img = 960
h_img = 540

train_labels['cx'] = train_labels['cx'] / w_img
train_labels['cy'] = train_labels['cy'] / h_img
train_labels['w'] = train_labels['w'] / w_img
train_labels['h'] = train_labels['h'] / h_img

# %%
# Normalize validation data
val_labels['cx'] = val_labels['cx'] / w_img
val_labels['cy'] = val_labels['cy'] / h_img
val_labels['w'] = val_labels['w'] / w_img
val_labels['h'] = val_labels['h'] / h_img

# %%
val_labels.head()
# Out:
#    img_id  class        cx        cy         w         h
# 0       1      5  0.263542  0.485185  0.100000  0.109259
# 1       1      5  0.128125  0.644444  0.156250  0.112963
# 2       1      5  0.173958  0.431481  0.079167  0.101852
# 3       1      6  0.291667  0.333333  0.078125  0.070370
# 4       1      5  0.867708  0.500000  0.131250  0.111111

# %%
#split labels per image

for i, g in train_labels.groupby(['img_id']):
    df = g[["class", "cx", "cy", "w", "h"]]
    #df['img_id'] = df['img_id'].astype(str).str.zfill(5)
    j = str(i).zfill(5) # to name the label file for each image same as the image name
    np.savetxt('/WAVE/users/unix/tpandey/yolov5/train/labels/'+j+'.txt', df.values, fmt="%.8g")

# %%
#split validation labels per image
for i, j in val_labels.groupby(['img_id']):
    df_val = j[["class", "cx", "cy", "w", "h"]]
    k = str(i).zfill(5) # to name the label file for each image same as the image name
    np.savetxt('val/labels/'+k+'.txt', df_val.values, fmt="%.8g")

# %%
# !python detect.py --source test/images/ --weights runs/train/exp21/weights/best.pt --img 960 --iou-thres 0.5 --save-txt --save-conf
# Out:
# detect: weights=['runs/train/exp21/weights/best.pt'], source=test/images/, data=data/coco128.yaml, imgsz=[960, 960], conf_thres=0.25, iou_thres=0.5, max_det=1000, device=, view_img=False, save_txt=True, save_conf=True, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False
# requirements: numpy>=1.18.5 not found and is required by YOLOv5, attempting auto-update...
# requirements: 'pip install numpy>=1.18.5' skipped (offline)
# requirements: opencv-python>=4.1.2 not found and is required by YOLOv5, attempting auto-update...
# requirements: 'pip install opencv-python>=4.1.2' skipped (offline)
# requirements: PyYAML>=5.3.1 not found and is required by YOLOv5, attempting auto-update...
# requirements: 'pip install PyYAML>=5.3.1' skipped (offline)
# ...

# %%
# save the inference result in the format mentioned in the assignment

import os
import glob

# %%
path = '/WAVE/users/unix/tpandey/yolov5/runs/detect/exp11/labels/'
txt_files = glob.glob(os.path.join(path, "*.txt"))

# %%
header_lst = ["class", "cx", "cy", "w", "h", "conf"]
image_id = txt_files[0].rsplit('/', 1)[1].split('.')[0]
main_dataframe = pd.read_csv(txt_files[0], names=header_lst, sep=" ").assign(img_id=image_id)

for i in range(1,len(txt_files)):
    image_id = txt_files[i].rsplit('/', 1)[1].split('.')[0]
    curr_df = pd.read_csv(txt_files[i], names=header_lst, sep=" ").assign(img_id=image_id)
    main_dataframe = pd.concat([main_dataframe,curr_df],axis=0)

# %%
main_dataframe['class'] = main_dataframe['class'] + 1

# %%
main_dataframe = main_dataframe[["img_id", "class", "cx", "cy", "w", "h", "conf"]]
np.savetxt('/WAVE/users/unix/tpandey/yolov5/output/output.txt', main_dataframe.values, fmt='%s')

# %%
#from utils.plots import plot_results
#plot_results('/WAVE/users/unix/tpandey/yolov5/runs/train/exp12/results.csv')  # plot 'results.csv' as 'results.png'

# %%
#!python train.py --img 960 --batch 32 --epochs 10 --data findVehicles.yaml --freeze 10
# Out:
# train: weights=yolov5s.pt, cfg=, data=findVehicles.yaml, hyp=data/hyps/hyp.scratch.yaml, epochs=10, batch_size=32, imgsz=960, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, evolve=None, bucket=, cache=None, image_weights=False, device=, multi_scale=False, single_cls=False, optimizer=SGD, sync_bn=False, workers=8, project=runs/train, name=exp, exist_ok=False, quad=False, linear_lr=False, label_smoothing=0.0, patience=100, freeze=[10], save_period=-1, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias=latest
# github: skipping check (not a git repository), for updates see https://github.com/ultralytics/yolov5
# requirements: numpy>=1.18.5 not found and is required by YOLOv5, attempting auto-update...
# requirements: 'pip install numpy>=1.18.5' skipped (offline)
# requirements: opencv-python>=4.1.2 not found and is required by YOLOv5, attempting auto-update...
# requirements: 'pip install opencv-python>=4.1.2' skipped (offline)
# ...
